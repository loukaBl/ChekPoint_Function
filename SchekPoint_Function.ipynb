# %% [markdown]
# <a href="https://colab.research.google.com/github/loukaBl/ChekPoint_Function/blob/main/SchekPoint_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculator(num1, num2):
    """
    Performs basic arithmetic operations on two numbers based on user-selected operator.
    Handles invalid operators and division by zero.
    """
    print(f"Using numbers: {num1} and {num2}")
    operator = input("Enter the operator (+, -, *, /): ").strip()

    if operator == '+':
        return num1 + num2
    elif operator == '-':
        return num1 - num2
    elif operator == '*':
        return num1 * num2
    elif operator == '/':
        if num2 == 0:
            return "Error: Division by zero is not allowed!"
        return num1 / num2
    else:
        return "Error: Invalid operator! Please use +, -, *, or /."

while True:
    try:
        print("\n=== Simple Calculator ===")
        num1 = float(input("Enter the first number: "))
        num2 = float(input("Enter the second number: "))

        result = calculator(num1, num2)
        print(f"The result is: {result}")

        again = input("\nDo you want to perform another calculation? (y/n): ").strip().lower()
        if again != 'y':
            print("Thank you for using the calculator!")
            break

    except ValueError:
        print("Error: Please enter valid numbers!")
    except KeyboardInterrupt:
        print("\n\nCalculator terminated by user.")
        break
# Out:
# === Simple Calculator ===
# Enter the first number: 12
# Enter the second number: 4
# Using numbers: 12.0 and 4.0
# Enter the operator (+, -, *, /): /
# The result is: 3.0
#
# Do you want to perform another calculation? (y/n): *
# Thank you for using the calculator!
